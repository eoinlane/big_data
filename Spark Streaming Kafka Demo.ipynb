# %%
from __future__ import print_function

import sys

from pyspark import SparkContext
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

# Create a local StreamingContext with two working thread and batch interval of 1 second
sc = SparkContext("local[2]", "KafkaDemo")
streamingContext = StreamingContext(sc, 1)

kafkaStream = KafkaUtils.createStream(streamingContext, 'localhost:2181', "spark-streaming-consumer", {'truckevent' :1})

lines = kafkaStream.map(lambda x: x[1])
counts = lines.flatMap(lambda line: line.split(" ")) .map(lambda word: (word, 1)).reduceByKey(lambda a, b: a+b)
counts.pprint()

# %%
streamingContext.start()             # Start the computation
streamingContext.awaitTermination()  # Wait for the computation to terminate
# Out:
# -------------------------------------------
# Time: 2015-07-10 14:32:33
# -------------------------------------------
#
# -------------------------------------------
# Time: 2015-07-10 14:32:34
# -------------------------------------------
#
# -------------------------------------------
# Time: 2015-07-10 14:32:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2015-07-10 14:32:36
# -------------------------------------------
#
# -------------------------------------------
# Time: 2015-07-10 14:32:37
# -------------------------------------------
#
# -------------------------------------------
# Time: 2015-07-10 14:32:38
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:37.275|1|11|Normal|-74.183712000000014|41.199339999999893', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:39
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:38.3|1|11|Normal|-74.184741000000031|41.197654000000057', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:40
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:39.302|1|11|Normal|-74.185069000000112|41.195903000000044', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:41
# -------------------------------------------
# (u'14:32:40.304|1|11|Normal|-74.183557999999948|41.186893000000055', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:42
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:41.307|1|11|Normal|-74.183496999999988|41.185316000000057', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:43
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:42.31|1|11|Normal|-74.183931999999913|41.183620000000019', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:44
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:43.312|1|11|Normal|-74.185907999999927|41.179313000000093', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:45
# -------------------------------------------
# (u'14:32:44.314|1|11|Normal|-74.186398999999938|41.178398000000016', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:46
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:45.316|1|11|Normal|-74.186572000000069|41.17807700000003', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:47
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:46.318|1|11|Normal|-74.186601999999993|41.178016000000071', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:48
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:47.32|1|11|Normal|-74.186795999999958|41.177654000000075', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:49
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:48.322|1|11|Normal|-74.188570999999911|41.174361999999974', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:50
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:49.325|1|11|Normal|-74.190837000000101|41.170673000000079', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:51
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:50.327|1|11|Normal|-74.191630000000032|41.168871999999965', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:52
# -------------------------------------------
# (u'14:32:51.33|1|11|Lane', 1)
# (u'2015-07-10', 1)
# (u'Departure|-74.192430999999942|41.163896999999906', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:53
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:52.333|1|11|Normal|-74.192561000000069|41.162876000000097', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:54
# -------------------------------------------
# (u'14:32:53.337|1|11|Normal|-74.191867000000002|41.160998999999947', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:55
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:54.34|1|11|Normal|-74.191683999999896|41.160122', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:56
# -------------------------------------------
# (u'14:32:55.343|1|11|Normal|-74.191737000000103|41.159220999999889', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:57
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:56.347|1|11|Normal|-74.193224999999984|41.156230999999934', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:58
# -------------------------------------------
# (u'14:32:57.349|1|11|Normal|-74.193690000000061|41.152552999999898', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:32:59
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:58.351|1|11|Normal|-74.193338999999924|41.150165000000015', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:00
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:32:59.354|1|11|Normal|-74.192984000000024|41.149286000000075', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:01
# -------------------------------------------
# (u'14:33:00.356|1|11|Normal|-74.192972999999938|41.149257000000034', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:02
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:01.358|1|11|Normal|-74.192712999999912|41.148707999999942', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:03
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:02.36|1|11|Normal|-74.192301000000043|41.148093999999901', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:04
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:03.363|1|11|Normal|-74.191675000000032|41.147858000000042', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:05
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:04.364|1|11|Normal|-74.189593000000059|41.145950000000084', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:06
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:05.367|1|11|Normal|-74.188204000000042|41.144614999999931', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:07
# -------------------------------------------
# (u'14:33:06.369|1|11|Normal|-74.185915000000023|41.143051000000014', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:08
# -------------------------------------------
# (u'14:33:07.372|1|11|Normal|-74.184946000000082|41.142624999999953', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:09
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:08.375|1|11|Normal|-74.183633999999984|41.141777000000047', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:10
# -------------------------------------------
# (u'14:33:09.38|1|11|Normal|-74.182612000000063|41.141513999999916', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:11
# -------------------------------------------
# (u'14:33:10.381|1|11|Normal|-74.179712999999992|41.14113599999996', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:12
# -------------------------------------------
# (u'14:33:11.383|1|11|Normal|-74.17737800000009|41.140540999999985', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:13
# -------------------------------------------
# (u'14:33:12.385|1|11|Normal|-74.174737999999934|41.140071999999918', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:14
# -------------------------------------------
# (u'14:33:13.387|1|11|Normal|-74.173181999999997|41.13982400000009', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:15
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:14.391|1|11|Normal|-74.171708999999964|41.139619000000039', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:16
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:15.394|1|11|Normal|-74.170176000000083|41.139267999999902', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:17
# -------------------------------------------
# (u'14:33:16.396|1|11|Normal|-74.169726000000082|41.139165000000048', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:18
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:17.399|1|11|Normal|-74.169092999999975|41.139018999999962', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:19
# -------------------------------------------
# (u'14:33:18.401|1|11|Normal|-74.168580999999904|41.138564999999971', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:20
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:19.404|1|11|Normal|-74.168161000000055|41.137917000000016', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:21
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:20.406|1|11|Normal|-74.167666000000054|41.136128000000099', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:22
# -------------------------------------------
# (u'14:33:21.408|1|11|Overspeed|-74.167429000000084|41.135295999999926', 1)
# (u'2015-07-10', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:23
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:22.412|1|11|Normal|-74.167779999999993|41.134645999999975', 1)
#
# -------------------------------------------
# Time: 2015-07-10 14:33:24
# -------------------------------------------
# (u'2015-07-10', 1)
# (u'14:33:23.415|1|11|Normal|-74.168173000000024|41.133915999999999', 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b230dbe3a15e> in <module>()
#       1 streamingContext.start()             # Start the computation
# ----> 2 streamingContext.awaitTermination()  # Wait for the computation to terminate
#
# /usr/hdp/current/spark-client/python/pyspark/streaming/context.pyc in awaitTermination(self, timeout)
#     188         """
#     189         if timeout is None:
# --> 190             self._jssc.awaitTermination()
#     191         else:
#     192             self._jssc.awaitTerminationOrTimeout(int(timeout * 1000))
#
# /usr/hdp/current/spark-client/python/build/py4j/java_gateway.pyc in __call__(self, *args)
#     534             END_COMMAND_PART
#     535
# --> 536         answer = self.gateway_client.send_command(command)
#     537         return_value = get_return_value(answer, self.gateway_client,
#     538                 self.target_id, self.name)
#
# /usr/hdp/current/spark-client/python/build/py4j/java_gateway.pyc in send_command(self, command, retry)
#     362         connection = self._get_connection()
#     363         try:
# --> 364             response = connection.send_command(command)
#     365             self._give_back_connection(connection)
#     366         except Py4JNetworkError:
#
# /usr/hdp/current/spark-client/python/build/py4j/java_gateway.pyc in send_command(self, command)
#     471         try:
#     472             self.socket.sendall(command.encode('utf-8'))
# --> 473             answer = smart_decode(self.stream.readline()[:-1])
#     474             logger.debug("Answer received: {0}".format(answer))
#     475             # Happens when a the other end is dead. There might be an empty
#
# /usr/local/lib/python2.7/socket.pyc in readline(self, size)
#     428                     try:
#     429                         while data != "\n":
# --> 430                             data = recv(1)
#     431                             if not data:
#     432                                 break
#
# KeyboardInterrupt:
